# %% [markdown]
# <a href="https://colab.research.google.com/github/chizkidd/deep-learning-models/blob/main/pytorch/rnn/rnn-gru-stacked-agnews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Deep Learning Models: A collection of various deep learning architectures, models, & their implementations (`PyTorch` or `TensorFlow`) in Jupyter Notebooks.
# * Author: _Chizoba Obasi_
# * Github Repo: https://github.com/chizkidd/deep-learning-models

# %%
# %%capture
# !pip install watermark
# !pip install torchinfo datasets

# %%
# %load_ext watermark
# %reload_ext watermark
# %watermark -a 'Chizoba Obasi' -v -p torch
# Out:
# Author: Chizoba Obasi
#
# Python implementation: CPython
# Python version       : 3.12.12
# IPython version      : 7.34.0
#
# torch: 2.10.0+cu128

# %% [markdown]
# ---
# # Stacked Gated Recurrent Unit (Stacked-GRU) Classifier on AG News
#
#
#
# ---
#
# # Stacked Gated Recurrent Unit (Stacked GRU) Classifier
#
# The network in this notebook is a **Stacked GRU** implemented from scratch on AG reviews dataset. Unlike a single-layer GRU, this architecture stacks multiple recurrent layers on top of each other. The output hidden state of the first layer serves as the input sequence for the second layer. Moving to a **Stacked GRU** (also known as a **Deep RNN**) is the transition from a "wide" model to a "deep" model. While the Bi-GRU focused on looking into the future, the Stacked GRU focuses on building a hierarchy of understanding—where lower layers pick up on syntax (grammar/word order) and higher layers pick up on semantics (overall meaning/sentiment).
# <br><br><br>
#
# **Network Architecture:**
#
# A Stacked GRU creates a **Deep Recurrent Neural Network**. In our 2-layer implementation, the first GRU processes the raw word embeddings. The second GRU then processes the sequence of "learned features" produced by the first layer. This allows the model to learn more complex, abstract representations of the text.
# <br><br><br>
#
# ---
#
# ### **Key Concepts of the `Stacked` Architecture:**
#
# 1. **Hierarchical Learning:** Layer 1 typically learns "local" patterns (like how "not" modifies "good"), while Layer 2 learns "global" patterns (how the whole sentence relates to the category).
# 2. **Vertical Information Flow:** At each time step $t$, the hidden state $h_t^{(1)}$ is passed not only to the next time step in its own layer but also upward as the input $x_t^{(2)}$ for the layer above it.
# 3. **Increased Capacity:** By adding layers, we increase the non-linearity of the model, allowing it to solve more complex classification tasks that a shallow model might struggle with.
# <br><br><br>
#
# ---
#
# ### **RNN Architecture Comparison Table**
#
# | Feature | Standard GRU | Bidirectional GRU | Stacked GRU (2-Layer) |
# | --- | --- | --- | --- |
# | **Primary Goal** | Temporal Memory | Temporal Context | **Hierarchical Abstraction** |
# | **Direction** | Forward Only | Both Directions | Forward (usually) |
# | **Depth** | Shallow (1 Layer) | Shallow (1 Layer) | **Deep (2+ Layers)** |
# | **Input to Layer** | Embeddings | Embeddings | **L1: Embeddings, L2: L1 Hidden States** |
# | **Logic** | $x \rightarrow h$ | $x \rightarrow h_{f}, h_{b}$ | **$x \rightarrow h^{(1)} \rightarrow h^{(2)}$** |
# | **Last State** | $h_T$ | $\text{concat}(h_{f,T}, h_{b,0})$ | **$h_T^{(2)}$ (The deepest state)** |
# | **Robustness** | Low (Vanishing grad) | Moderate (Context) | **High (Better Feature Extraction)** |
# <br><br><br>
#
# ---
#
# ### **The "Robust" Depth Logic**
#
# When implementing this from scratch, we must be careful with the dimensions between layers.
#
# * **Layer 1:** Input size = `embed_dim`, Output size = `hidden_size`.
# * **Layer 2:** Input size = `hidden_size`, Output size = `hidden_size`.
#
# _"Following the principles in **Pascanu et al. (2013) [1]**, this implementation uses a stacked (deep) architecture. While a single-layer GRU captures temporal dependencies, adding a second layer allows the model to form a hierarchy of representations—effectively allowing 'Layer 2' to process the 'concepts' identified by 'Layer 1'."_
#
# <br><br><br>
#
# ---
#
# ### **A Technical Note on "Last States"**
#
# In a Stacked GRU, we only care about the **final hidden state of the very last layer** ($h_T^{(2)}$) for the final classification. This state represents the "summary of summaries."
#
# <br><br><br>
#
# ---
#
#
# **REFERENCES:**
#
# 1. Pascanu, R., Gulcehre, C., & Bengio, Y. (2013). ["How to Construct Deep Recurrent Neural Networks."](https://arxiv.org/abs/1312.6026) *arXiv preprint arXiv:1312.6026*. **(Deep RNN Architecture)**
# 2. Cho, Kyunghyun, et al. ["Learning Phrase Representations using RNN Encoder-Decoder for Statistical Machine Translation."](https://arxiv.org/abs/1406.1078) *arXiv preprint arXiv:1406.1078*, 2014. **(Original GRU Paper)**
# 3. Chung, J., Gulcehre, C., Cho, K., & Bengio, Y. (2014). ["Empirical Evaluation of Gated Recurrent Neural Networks on Sequence Modeling."](https://arxiv.org/abs/1412.3555) *arXiv preprint arXiv:1412.3555*. **(GRU vs LSTM Comparison)**
# 4. Zhang, Xiang, Junbo Zhao, and Yann LeCun. ["Character-level Convolutional Networks for Text Classification."](https://arxiv.org/abs/1509.01626) *Advances in Neural Information Processing Systems (NeurIPS)*, 2015.
# 5. Gulli, Antonio. ["AG's Corpus of News Articles."](http://groups.di.unipi.it/~gulli/AG_corpus_of_news_articles.html) 2004.
# 6. Google. (2026). ["Gemini 3 Flash"](https://gemini.google.com/) [Large language model]. Google AI
#
#
# ---

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
from datasets import load_dataset, DatasetDict
from collections import Counter


# from torch.cuda.amp import GradScaler, autocast
from torch.amp import GradScaler, autocast
from torchinfo import summary

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import numpy as np
import math
import time
import os
import random
import re

if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %%
def set_all_seeds(seed):
    os.environ["PL_GLOBAL_SEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# %% [markdown]
# ---
# # 0. Model Hyperparameters
# ---

# %%
##########################
### SETTINGS
##########################

# Hyperparameters
RANDOM_SEED = 123
BATCH_SIZE = 128
LEARNING_RATE = 0.001
NUM_EPOCHS = 20
NUM_CLASSES = 1

VOCABULARY_SIZE = 20000

EMBEDDING_DIM = 128
HIDDEN_DIM = 256
# OUTPUT_DIM = 1

# Set device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(DEVICE)
# Out:
# cuda

# %% [markdown]
# ---
# # 1. Data Preparation & Loading
#
# ---

# %%
# 1. Load Dataset (IMDB)
raw_datasets = load_dataset("ag_news")


# 2. Split 10% of 'train' to create a 'validation' set (seed for reproducibility)
train_val_split = raw_datasets["train"].train_test_split(test_size=0.1, seed=RANDOM_SEED)

ds_splits = DatasetDict({
    'train': train_val_split['train'],
    'validation': train_val_split['test'], # The 10% we just carved out
    'test': raw_datasets['test']
})

print(ds_splits)

# 2. Build Vocabulary (From Scratch Logic)
tokenizer = lambda text: re.findall(r'\w+', text.lower())
word_counts = Counter()

# Important: We only iterate over ds_splits['train']
for text in ds_splits['train']['text']:
    word_counts.update(tokenizer(text))

# Filter rare words and create mapping: : <PAD>=0, <UNK>=1, then top 20k words
vocab = {word: i + 2 for i, (word, count) in enumerate(word_counts.most_common(VOCABULARY_SIZE))}
vocab['<PAD>'] = 0
vocab['<UNK>'] = 1

print(f"Vocab size: {len(vocab)}")

# 3. Custom Dataset Class
class TextDataset(torch.utils.data.Dataset):
    def __init__(self, dataset_split):
        self.data = dataset_split

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Return raw text and label. Let collate_fn handle the rest.
        item = self.data[idx]
        return item['text'], item['label']

# 4. Robust Text Pipeline
def text_pipeline(text, max_len=128):
    tokens = tokenizer(text)
    # Use .get(t, 1) because 1 is your <UNK> index
    return [vocab.get(t, 1) for t in tokens][:max_len]

# 5. Robust Collate Batch
def collate_batch(batch):
    label_list, text_list, lengths = [], [], []

    for _text, _label in batch:
        # 1. Labels: Use LONG for AG News (Multi-class)
        label_list.append(_label)

        # 2. Numericalize and Truncate
        processed_text = torch.tensor(text_pipeline(_text), dtype=torch.int64)
        text_list.append(processed_text)
        lengths.append(processed_text.size(0))

    # 3. Padding logic
    # We use <PAD> index 0. We use vocab.get just in case names change.
    pad_idx = vocab.get('<PAD>', 0)

    # This dynamically pads to the longest sequence in THIS batch (more efficient)
    text_list_padded = pad_sequence(text_list, batch_first=True, padding_value=pad_idx)
    label_tensor = torch.tensor(label_list, dtype=torch.long)
    length_tensor = torch.tensor(lengths, dtype=torch.int64)

    return text_list_padded.to(DEVICE), label_tensor.to(DEVICE), length_tensor.to(DEVICE)

# 6. Initialize DataLoaders
train_ds = TextDataset(ds_splits['train'])
val_ds   = TextDataset(ds_splits['validation'])
test_ds  = TextDataset(ds_splits['test'])

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_batch)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_batch)
test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_batch)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/18.6M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/1.23M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/120000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/7600 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 108000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 12000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 7600
#     })
# })
# Vocab size: 20002

# %% [markdown]
# ---
# # 2. Model Creation
#
# ---

# %%
class GRUCellFromScratch(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        self.hidden_size = hidden_size

        # We need weights for 3 operations:
        # Update gate (z), Reset gate (r), and Candidate hidden state (h_tilde)
        self.gate_weights = nn.Linear(input_size + hidden_size, 2 * hidden_size)
        self.candidate_weights = nn.Linear(input_size + hidden_size, hidden_size)

    def forward(self, x, h_prev):
        # x: [batch, input_size]
        # h_prev: [batch, hidden_size]

        # 1. Calculate Update (z) and Reset (r) gates
        combined = torch.cat((x, h_prev), dim=1)
        gates = torch.sigmoid(self.gate_weights(combined))
        z_gate, r_gate = gates.chunk(2, dim=1)

        # 2. Calculate Candidate Hidden State (h_tilde)
        # We use the Reset gate to "mask" the previous hidden state
        combined_candidate = torch.cat((x, r_gate * h_prev), dim=1)
        h_tilde = torch.tanh(self.candidate_weights(combined_candidate))

        # 3. Final Hidden State update
        # This is a linear interpolation between past and candidate
        h_curr = (1 - z_gate) * h_prev + z_gate * h_tilde

        return h_curr

# %%
class StackedGRUFromScratch(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_size, output_size):
        super().__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(vocab_size, embed_dim)

        # Layer 1: Input is Embedding
        self.gru1 = GRUCellFromScratch(embed_dim, hidden_size)

        # Layer 2: Input is the output of Layer 1 (hidden_size)
        self.gru2 = GRUCellFromScratch(hidden_size, hidden_size)

        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, lengths=None):
        if isinstance(x, (list, tuple)) and lengths is None:
            x, lengths = x

        batch_size, seq_len = x.shape
        x = self.embedding(x)

        # Initialize hidden states for both layers
        h1 = torch.zeros(batch_size, self.hidden_size).to(x.device)
        h2 = torch.zeros(batch_size, self.hidden_size).to(x.device)

        # --- LAYER 1 ---
        # We must collect the outputs to pass as a sequence to Layer 2
        l1_outputs = []
        for t in range(seq_len):
            h1 = self.gru1(x[:, t, :], h1)
            l1_outputs.append(h1.unsqueeze(1)) # [Batch, 1, Hidden]

        # Combine into a sequence: [Batch, Seq, Hidden]
        l1_seq = torch.cat(l1_outputs, dim=1)

        # --- LAYER 2 ---
        all_h2 = []
        for t in range(seq_len):
            # Input to L2 is the output of L1 at this time step
            h2 = self.gru2(l1_seq[:, t, :], h2)
            all_h2.append(h2.unsqueeze(1))

        all_h2 = torch.cat(all_h2, dim=1)

        # --- ROBUST INDEXING ---
        # We take the final state of the second (top) layer
        idx = (lengths - 1).view(-1, 1, 1).expand(batch_size, 1, self.hidden_size)
        last_h2 = all_h2.gather(1, idx).squeeze(1)

        return self.fc(last_h2)

# %%
def get_percentile_length(dataset, tokenizer, p=95):
    # Unpack the tuple directly
    lengths = []
    for text, label in dataset:
        tokens = tokenizer(text)
        lengths.append(len(tokens))

    return int(np.percentile(lengths, p))

_MAX_LEN = get_percentile_length(train_ds, tokenizer, p=95)
print(f"95% of sequences are shorter than {_MAX_LEN} tokens.")
# Out:
# 95% of sequences are shorter than 58 tokens.

# %%
def get_robust_maxlen(dataset, tokenizer, p=95, absolute_max=512):
    # 1. Get the statistical length
    lengths = [len(tokenizer(ex[0])) for ex in dataset]
    p_length = np.percentile(lengths, p)

    # 2. Find the next power of 2
    # math.log2 gives the exponent, ceil rounds up, 2** raises it back
    # We use max(16, ...) to ensure we don't get a tiny length like 4 or 8
    robust_len = 2 ** math.ceil(math.log2(max(16, p_length)))

    # 3. Cap at absolute_max
    final_len = min(robust_len, absolute_max)

    print(f"{p}th Percentile: {p_length:.2f}")
    print(f"Nearest Power of 2: {robust_len}")
    print(f"Final Robust MAX_LEN: {final_len}")

    return final_len

# Usage
__MAX_LEN = get_robust_maxlen(train_ds, tokenizer, p=95)
# Out:
# 95th Percentile: 58.00
# Nearest Power of 2: 64
# Final Robust MAX_LEN: 64

# %%
VOCAB_SIZE = len(vocab)
MAX_LEN = __MAX_LEN
print(MAX_LEN)
# Out:
# 64

# %%
# --- Configuration Switch ---
DATASET_NAME = "ag-news"

if DATASET_NAME == "IMDB":
    IS_BINARY = True
    NUM_CLASSES = 1
    # criterion = nn.BCEWithLogitsLoss()
else:
    IS_BINARY = False
    NUM_CLASSES = 4 # AG News has 4 classes
    # criterion = nn.CrossEntropyLoss()

# %%
set_all_seeds(RANDOM_SEED)
model = StackedGRUFromScratch(
    vocab_size=VOCAB_SIZE,
    embed_dim=EMBEDDING_DIM,
    hidden_size=HIDDEN_DIM,
    output_size=NUM_CLASSES
).to(DEVICE)

summary(model,
        input_data=(torch.zeros((BATCH_SIZE, MAX_LEN), dtype=torch.long).to(DEVICE),
                    torch.ones((BATCH_SIZE,), dtype=torch.long).to(DEVICE) * MAX_LEN),
        col_names=["input_size", "output_size", "num_params", "mult_adds"],
        device=DEVICE)
# Out:
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Mult-Adds
# ============================================================================================================================================
# StackedGRUFromScratch                    [128, 64]                 [128, 4]                  --                        --
# ├─Embedding: 1-1                         [128, 64]                 [128, 64, 128]            2,560,256                 327,712,768
# ├─GRUCellFromScratch: 1-2                [128, 128]                [128, 256]                --                        --
# │    └─Linear: 2-1                       [128, 384]                [128, 512]                197,120                   25,231,360
# │    └─Linear: 2-2                       [128, 384]                [128, 256]                98,560                    12,615,680
# ├─GRUCellFromScratch: 1-3                [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-3                       [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-4                       [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-4                [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-5                       [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-6                       [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-5                [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-7                       [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-8                       [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-6                [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-9                       [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-10                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-7                [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-11                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-12                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-8                [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-13                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-14                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-9                [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-15                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-16                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-10               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-17                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-18                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-11               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-19                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-20                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-12               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-21                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-22                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-13               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-23                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-24                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-14               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-25                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-26                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-15               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-27                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-28                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-16               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-29                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-30                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-17               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-31                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-32                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-18               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-33                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-34                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-19               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-35                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-36                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-20               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-37                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-38                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-21               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-39                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-40                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-22               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-41                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-42                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-23               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-43                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-44                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-24               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-45                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-46                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-25               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-47                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-48                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-26               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-49                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-50                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-27               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-51                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-52                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-28               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-53                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-54                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-29               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-55                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-56                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-30               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-57                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-58                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-31               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-59                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-60                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-32               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-61                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-62                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-33               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-63                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-64                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-34               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-65                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-66                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-35               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-67                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-68                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-36               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-69                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-70                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-37               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-71                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-72                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-38               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-73                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-74                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-39               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-75                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-76                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-40               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-77                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-78                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-41               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-79                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-80                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-42               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-81                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-82                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-43               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-83                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-84                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-44               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-85                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-86                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-45               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-87                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-88                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-46               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-89                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-90                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-47               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-91                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-92                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-48               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-93                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-94                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-49               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-95                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-96                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-50               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-97                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-98                      [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-51               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-99                      [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-100                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-52               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-101                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-102                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-53               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-103                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-104                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-54               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-105                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-106                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-55               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-107                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-108                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-56               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-109                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-110                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-57               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-111                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-112                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-58               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-113                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-114                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-59               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-115                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-116                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-60               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-117                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-118                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-61               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-119                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-120                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-62               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-121                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-122                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-63               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-123                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-124                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-64               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-125                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-126                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-65               [128, 128]                [128, 256]                (recursive)               --
# │    └─Linear: 2-127                     [128, 384]                [128, 512]                (recursive)               25,231,360
# │    └─Linear: 2-128                     [128, 384]                [128, 256]                (recursive)               12,615,680
# ├─GRUCellFromScratch: 1-66               [128, 256]                [128, 256]                --                        --
# │    └─Linear: 2-129                     [128, 512]                [128, 512]                262,656                   33,619,968
# │    └─Linear: 2-130                     [128, 512]                [128, 256]                131,328                   16,809,984
# ├─GRUCellFromScratch: 1-67               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-131                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-132                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-68               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-133                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-134                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-69               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-135                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-136                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-70               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-137                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-138                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-71               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-139                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-140                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-72               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-141                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-142                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-73               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-143                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-144                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-74               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-145                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-146                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-75               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-147                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-148                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-76               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-149                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-150                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-77               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-151                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-152                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-78               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-153                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-154                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-79               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-155                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-156                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-80               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-157                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-158                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-81               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-159                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-160                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-82               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-161                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-162                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-83               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-163                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-164                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-84               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-165                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-166                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-85               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-167                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-168                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-86               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-169                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-170                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-87               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-171                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-172                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-88               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-173                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-174                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-89               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-175                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-176                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-90               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-177                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-178                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-91               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-179                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-180                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-92               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-181                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-182                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-93               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-183                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-184                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-94               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-185                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-186                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-95               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-187                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-188                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-96               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-189                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-190                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-97               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-191                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-192                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-98               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-193                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-194                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-99               [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-195                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-196                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-100              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-197                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-198                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-101              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-199                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-200                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-102              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-201                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-202                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-103              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-203                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-204                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-104              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-205                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-206                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-105              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-207                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-208                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-106              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-209                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-210                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-107              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-211                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-212                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-108              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-213                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-214                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-109              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-215                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-216                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-110              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-217                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-218                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-111              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-219                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-220                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-112              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-221                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-222                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-113              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-223                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-224                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-114              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-225                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-226                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-115              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-227                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-228                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-116              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-229                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-230                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-117              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-231                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-232                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-118              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-233                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-234                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-119              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-235                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-236                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-120              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-237                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-238                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-121              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-239                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-240                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-122              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-241                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-242                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-123              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-243                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-244                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-124              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-245                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-246                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-125              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-247                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-248                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-126              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-249                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-250                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-127              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-251                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-252                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-128              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-253                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-254                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─GRUCellFromScratch: 1-129              [128, 256]                [128, 256]                (recursive)               --
# │    └─Linear: 2-255                     [128, 512]                [128, 512]                (recursive)               33,619,968
# │    └─Linear: 2-256                     [128, 512]                [128, 256]                (recursive)               16,809,984
# ├─Linear: 1-130                          [128, 256]                [128, 4]                  1,028                     131,584
# ============================================================================================================================================
# Total params: 3,250,948
# Trainable params: 3,250,948
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 5.98
# ============================================================================================================================================
# Input size (MB): 0.07
# Forward/backward pass size (MB): 109.06
# Params size (MB): 13.00
# Estimated Total Size (MB): 122.13
# ============================================================================================================================================

# %% [markdown]
# ---
# # 3. Model Training, Testing & Evaluation
#
# ---

# %%
def calculate_accuracy(loader, model, device, is_binary=True):
    model.eval()
    correct, total = 0, 0

    with torch.no_grad():
        for inputs, labels, lengths in loader:
            inputs, labels, lengths = inputs.to(device), labels.to(device), lengths.to(device)
            logits = model(inputs, lengths)

            if is_binary:
                predicted = (torch.sigmoid(logits.view(-1)) > 0.5).long()
            else:
                _, predicted = torch.max(logits.data, 1)

            total += labels.size(0)
            correct += (predicted == labels.long()).sum().item()

    return 100 * correct / total

# %%
IS_BINARY, NUM_CLASSES
# Out:
# (False, 4)

# %%
# 1. Update Optimizer and Scheduler
# Binary uses BCEWithLogitsLoss; Multi-class uses CrossEntropy
criterion = nn.BCEWithLogitsLoss() if IS_BINARY else nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# Robust Scheduler: Cosine Annealing
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)

# %%
start_time = time.time()
history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': [], 'lrs': []}

print(f"Starting training on {DEVICE}...")

for epoch in range(NUM_EPOCHS):
    model.train()
    running_loss = 0.0

    # 1. Training Phase
    for i, (inputs, labels, lengths) in enumerate(train_loader):
        inputs, labels, lengths = inputs.to(DEVICE), labels.to(DEVICE), lengths.to(DEVICE)

        optimizer.zero_grad()

        # Forward pass (passing lengths for masking logic)
        logits = model(inputs, lengths)

        if IS_BINARY:
            loss = criterion(logits.squeeze(), labels.float())
        else:
            loss = criterion(logits, labels.long())

        loss.backward()

        # --- ROBUST RNN FIX: Gradient Clipping ---
        # Prevents gradients from "exploding" during the backprop through time (BPTT)
        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        optimizer.step()
        running_loss += loss.item() * inputs.size(0)

    # 2. Metrics Calculation
    # Note: Using the updated calculate_accuracy that handles (inputs, lengths)
    train_loss = running_loss / len(train_ds)
    train_acc = calculate_accuracy(train_loader, model, DEVICE, is_binary=IS_BINARY)

    # 3. Validation Phase
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for inputs, labels, lengths in val_loader:
            inputs, labels, lengths = inputs.to(DEVICE), labels.to(DEVICE), lengths.to(DEVICE)

            logits = model(inputs, lengths)

            if IS_BINARY:
                loss = criterion(logits.squeeze(), labels.float())
            else:
                loss = criterion(logits, labels.long())

            val_loss += loss.item() * inputs.size(0)

    val_loss /= len(val_ds)
    val_acc = calculate_accuracy(val_loader, model, DEVICE, is_binary=IS_BINARY)

    scheduler.step()
    current_lr = optimizer.param_groups[0]['lr']

    # 4. Logging
    history['train_loss'].append(train_loss)
    history['val_loss'].append(val_loss)
    history['train_acc'].append(train_acc)
    history['val_acc'].append(val_acc)
    history['lrs'].append(current_lr)

    print(f'Epoch {epoch + 1}/{NUM_EPOCHS} | '
          f'Loss (train/val): {train_loss:.4f} / {val_loss:.4f} | '
          f'Acc (train/val): {train_acc:.2f}% / {val_acc:.2f}% | '
          f'LR: {current_lr:.6f}')

print('\nTotal Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Starting training on cuda...
# Epoch 1/20 | Loss (train/val): 0.5000 / 0.3230 | Acc (train/val): 91.21% / 89.43% | LR: 0.000994
# Epoch 2/20 | Loss (train/val): 0.2585 / 0.2853 | Acc (train/val): 93.63% / 90.19% | LR: 0.000976
# Epoch 3/20 | Loss (train/val): 0.1860 / 0.2754 | Acc (train/val): 95.90% / 90.53% | LR: 0.000946
# Epoch 4/20 | Loss (train/val): 0.1328 / 0.3091 | Acc (train/val): 97.40% / 90.72% | LR: 0.000905
# Epoch 5/20 | Loss (train/val): 0.0871 / 0.3377 | Acc (train/val): 98.47% / 90.68% | LR: 0.000854
# Epoch 6/20 | Loss (train/val): 0.0555 / 0.3723 | Acc (train/val): 98.81% / 90.38% | LR: 0.000794
# Epoch 7/20 | Loss (train/val): 0.0355 / 0.4598 | Acc (train/val): 99.36% / 90.60% | LR: 0.000727
# Epoch 8/20 | Loss (train/val): 0.0225 / 0.4942 | Acc (train/val): 99.47% / 90.53% | LR: 0.000655
# Epoch 9/20 | Loss (train/val): 0.0159 / 0.5279 | Acc (train/val): 99.71% / 90.80% | LR: 0.000578
# Epoch 10/20 | Loss (train/val): 0.0104 / 0.5926 | Acc (train/val): 99.81% / 90.82% | LR: 0.000500
# Epoch 11/20 | Loss (train/val): 0.0074 / 0.5967 | Acc (train/val): 99.88% / 90.85% | LR: 0.000422
# Epoch 12/20 | Loss (train/val): 0.0050 / 0.6285 | Acc (train/val): 99.82% / 90.69% | LR: 0.000345
# Epoch 13/20 | Loss (train/val): 0.0034 / 0.6751 | Acc (train/val): 99.95% / 90.97% | LR: 0.000273
# Epoch 14/20 | Loss (train/val): 0.0021 / 0.7096 | Acc (train/val): 99.94% / 90.84% | LR: 0.000206
# Epoch 15/20 | Loss (train/val): 0.0015 / 0.7076 | Acc (train/val): 99.96% / 91.01% | LR: 0.000146
# Epoch 16/20 | Loss (train/val): 0.0011 / 0.7381 | Acc (train/val): 99.97% / 90.99% | LR: 0.000095
# Epoch 17/20 | Loss (train/val): 0.0008 / 0.7547 | Acc (train/val): 99.97% / 90.97% | LR: 0.000054
# Epoch 18/20 | Loss (train/val): 0.0006 / 0.7775 | Acc (train/val): 99.97% / 90.95% | LR: 0.000024
# Epoch 19/20 | Loss (train/val): 0.0005 / 0.7875 | Acc (train/val): 99.98% / 90.98% | LR: 0.000006
# Epoch 20/20 | Loss (train/val): 0.0004 / 0.7903 | Acc (train/val): 99.98% / 90.99% | LR: 0.000000
#
# Total Training Time: 73.31 min

# %%
# --- Final Evaluation ---
test_accuracy = calculate_accuracy(test_loader, model, DEVICE, is_binary=IS_BINARY)
print(f'\nFinal Test Accuracy: {test_accuracy:.2f}%')
# Out:
# Final Test Accuracy: 90.91%

# %%
def plot_history(history):
    """
    Plots the training and validation loss, accuracy, and learning rate
    from a PyTorch history dictionary.

    Args:
        history (dict): Dictionary containing training metrics.
                        Expected keys: 'train_loss', 'val_loss', 'train_acc', 'val_acc', 'lrs'.
    """
    epochs = range(len(history['train_loss']))

    plt.figure(figsize=(18, 5))

    # Plot 1: Loss
    plt.subplot(1, 3, 1)
    plt.plot(epochs, history['train_loss'], label='Training Loss')
    plt.plot(epochs, history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    # plt.grid(True)

    # Plot 2: Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(epochs, history['train_acc'], label='Training Accuracy')
    plt.plot(epochs, history['val_acc'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    # plt.grid(True)

    # Plot 3: Learning Rate
    plt.subplot(1, 3, 3)
    plt.plot(epochs, history['lrs'], label='Learning Rate', color='orange')
    plt.title('Learning Rate')
    plt.xlabel('Epochs')
    plt.ylabel('Learning Rate')
    plt.legend()
    # plt.grid(True)

    plt.tight_layout()
    plt.show()
    # plt.savefig()

plot_history(history)

# %% [markdown]
# ---
# ## 4. Model Inference and Sentiment Prediction
#
# ---

# %%
# 1. Define the Human Labels
ag_news_labels = {0: "World", 1: "Sports", 2: "Business", 3: "Sci/Tech"}

# 2. Re-use your Training Tokenizer
# This ensures "Don't" becomes ["don", "t"] consistently in both phases
tokenizer = lambda text: re.findall(r'\w+', text.lower())


# Adapted the below code from:
# https://github.com/bentrevett/pytorch-sentiment-analysis/blob/experimental/2%20-%20Upgraded%20Sentiment%20Analysis.ipynb
def predict_topic(model, sentence):
    model.eval()

    # Step A: Tokenize exactly like training
    tokens = tokenizer(sentence)

    # Step B: Numericalize using the <UNK> index (1)
    indexed = [vocab.get(t, 1) for t in tokens]

    # Step C: Prepare Tensors [Batch, Seq_Len]
    tensor = torch.LongTensor(indexed).unsqueeze(0).to(DEVICE)
    length = torch.LongTensor([len(indexed)]).to(DEVICE)

    with torch.no_grad():
        # Step D: Forward Pass
        logits = model(tensor, length)

        # Step E: Get the highest score
        # Using softmax to see the confidence %
        probs = torch.softmax(logits, dim=1)
        prediction_idx = torch.argmax(probs, dim=1).item()
        confidence = probs[0][prediction_idx].item()

    return ag_news_labels[prediction_idx], confidence

# --- Test ----------------------------------------
headline = "The Olympic games were postponed due to global health concerns."
topic, score = predict_topic(model, headline)
print(f"Result: {topic} ({score:.2%})")
# Out:
# Result: Sports (100.00%)

# %%
# Create a list of test cases
ag_news_tests = [
    "The Federal Reserve is expected to keep interest rates steady as inflation cools.", # Business
    "The star striker scored a hat-trick in the final minutes of the world cup qualifier.", # Sports
    "Astronomers have discovered a new Earth-like planet orbiting a distant star system.", # Sci/Tech
    "Protests erupted in the capital city following the controversial election results.",    # World
    "New software update fixes critical security vulnerabilities in mobile operating systems." # Sci/Tech
]

print(f"{'Headline':<60} | {'Predicted Topic':<12} | {'Confidence'}")
print("-" * 85)

for text in ag_news_tests:
    topic, conf = predict_topic(model, text)
    print(f"{text[:58]:<60} | {topic:<12} | {conf:.2%}")
# Out:
# Headline                                                     | Predicted Topic | Confidence
# -------------------------------------------------------------------------------------
# The Federal Reserve is expected to keep interest rates ste   | Business     | 100.00%
# The star striker scored a hat-trick in the final minutes o   | Sports       | 100.00%
# Astronomers have discovered a new Earth-like planet orbiti   | Sci/Tech     | 99.97%
# Protests erupted in the capital city following the controv   | World        | 99.98%
# New software update fixes critical security vulnerabilitie   | Sci/Tech     | 100.00%

# %%
# %watermark -iv
# Out:
# datasets   : 4.0.0
# matplotlib : 3.10.0
# numpy      : 2.0.2
# pandas     : 2.2.2
# re         : 2.2.1
# sklearn    : 1.6.1
# torch      : 2.10.0+cu128
# torchinfo  : 1.8.0
# torchvision: 0.25.0+cu128
